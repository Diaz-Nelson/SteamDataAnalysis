# %%
from functions import data_funcs

game_data, details_failed, game_failed, tags_failed  = data_funcs.get_game_data()
# Out:
# [INFO] Scraping Steam Charts...
# [INFO] Getting each game's details via Steam API...
# Failed to retrieve details for 480
# [INFO] Getting tags and reviews...
# FAILED TO GET TAGS FOR 480
# Failed to get tags or Review Counts for 480
# [INFO] Combining dataframes...
# [SUCCESS] Game data successfully compiled.

# %%
print(game_data)
# Out:
#    Rank                       Game  Current     Peak   App ID Player Hours  \
# 0    1.           Counter-Strike 2  1165042  1597285      730    717345510
# 1    2.                     Dota 2   785388   858940      570    403249201
# 2    3.                ARC Raiders   299115   459483  1808500     19385135
# 3    4.        PUBG: BATTLEGROUNDS   297363   750442   578080    198057757
# 4    5.             Battlefield™ 6   254086   656067  2807960    224008460
# 5    6.                       Rust   135231   184595   252490     71638800
# 6    7.              Path of Exile    95688   184633   238960     27249788
# 7    8.                  Bongo Cat    93725   125794  3419430     66244904
# 8    9.                     Banana    93652   120346  2923300     67834660
# 9   10.               Apex Legends    92342   229804  1172470     58721813
# 10  11.           Wallpaper Engine    84487   148230   431960     60988838
# 11  12.  Grand Theft Auto V Legacy    81427   108952   271590     44327649
# 12  13.                Delta Force    77417   220559  2507950     69659166
# 13  14.                War Thunder    72029    97370   236390     38337981
# 14  15.        Football Manager 26    67449    82750  3551340      7128461
# 15  16.           Dead by Daylight    61996    90008   381210     38700073
# 16  17.                   Warframe    61854    86545   230410     39029004
# 17  18.         Escape from Duckov    61232   301322  3167020     66377812
# 18  19.                   R.E.P.O.    56497   193551  3241660     28627032
# 19  20.       Europa Universalis V    56467    72816  3450310      6692311
# 20  21.                   Spacewar    56238    89228      480     31801009
# 21  22.              Marvel Rivals    51883   127557  2767030     45132553
# 22  23.                Crosshair X    50289    61818  1366800     29345819
# 23  24.             Stardew Valley    49882   131255   413150     42006181
# 24  25.            Baldur's Gate 3    49588    82792  1086940     33722981
#
#                                                Genres  Release Date  \
# 0                              [Action, Free To Play]  Aug 21, 2012
# 1                    [Action, Strategy, Free To Play]   Jul 9, 2013
# 2                                            [Action]  Oct 30, 2025
# 3   [Action, Adventure, Massively Multiplayer, Fre...  Dec 21, 2017
# 4                                            [Action]  Oct 10, 2025
# 5   [Action, Adventure, Indie, Massively Multiplay...   Feb 8, 2018
# 6   [Action, Adventure, Indie, Massively Multiplay...  Oct 23, 2013
# 7   [Casual, Indie, Massively Multiplayer, Simulat...   Mar 5, 2025
# 8   [Adventure, Casual, Simulation, Strategy, Free...  Apr 23, 2024
# 9                   [Action, Adventure, Free To Play]   Nov 4, 2020
# 10  [Casual, Indie, Animation & Modeling, Design &...  Nov 16, 2018
# 11                                [Action, Adventure]  Apr 13, 2015
# 12  [Action, Adventure, Massively Multiplayer, Fre...   Dec 4, 2024
# 13  [Action, Massively Multiplayer, Simulation, Fr...  Aug 15, 2013
# 14                     [Simulation, Sports, Strategy]   Nov 4, 2025
# 15                                           [Action]  Jun 14, 2016
# 16                        [Action, RPG, Free To Play]  Mar 25, 2013
# 17                    [Action, Adventure, Indie, RPG]  Oct 16, 2025
# 18                             [Action, Early Access]  Feb 26, 2025
# 19                                         [Strategy]   Nov 4, 2025
# 20                                             [None]          None
# 21                             [Action, Free To Play]   Dec 5, 2024
# 22  [Action, Adventure, Indie, Animation & Modelin...  Aug 17, 2020
# 23                           [Indie, RPG, Simulation]  Feb 26, 2016
# 24                         [Adventure, RPG, Strategy]   Aug 3, 2023
#
#     Days Since Release                                               Tags  \
# 0               4830.0  [FPS, Shooter, Multiplayer, Competitive, Actio...
# 1               4508.0  [Free to Play, MOBA, Multiplayer, Strategy, eS...
# 2                 12.0  [Extraction Shooter, PvP, Third-Person Shooter...
# 3               2882.0  [Survival, Shooter, Battle Royale, Multiplayer...
# 4                 32.0  [FPS, Multiplayer, Action, Singleplayer, Milit...
# 5               2833.0  [Survival, Crafting, Multiplayer, Open World, ...
# 6               4402.0  [Free to Play, Dark Fantasy, Action RPG, Hack ...
# 7                251.0  [Cats, Free to Play, Clicker, Cute, Casual, Id...
# 8                567.0  [Free to Play, Clicker, Singleplayer, 2D, Casu...
# 9               1833.0  [Free to Play, Multiplayer, Battle Royale, FPS...
# 10              2552.0  [Mature, Utilities, Anime, Software, Design & ...
# 11              3865.0  [Open World, Action, Multiplayer, Crime, Autom...
# 12               342.0  [Free to Play, FPS, Extraction Shooter, Single...
# 13              4471.0  [Free to Play, Simulation, Vehicular Combat, C...
# 14                 7.0  [Simulation, Sports, Strategy, Football (Socce...
# 15              3437.0  [Horror, Multiplayer, Survival Horror, Online ...
# 16              4614.0  [Free to Play, Looter Shooter, Action RPG, Thi...
# 17                26.0  [Adventure, Action, Extraction Shooter, Top-Do...
# 18               258.0  [Horror, Online Co-Op, Multiplayer, Comedy, Co...
# 19                 7.0  [Resource Management, Grand Strategy, 4X, Trad...
# 20                 NaN                                             [None]
# 21               341.0  [Free to Play, Multiplayer, Hero Shooter, Thir...
# 22              1912.0  [Action, Indie, Utilities, Adventure, Shooter,...
# 23              3546.0  [Farming Sim, Pixel Graphics, Multiplayer, Lif...
# 24               831.0  [RPG, Character Customization, Choices Matter,...
#
#     Recent Review Score  Recent Review Count  All Review Score  \
# 0                   8.0              86514.0               8.0
# 1                   6.0              21179.0               8.0
# 2                   8.0              48133.0               8.0
# 3                   5.0              14917.0               5.0
# 4                   5.0             139669.0               6.0
# 5                   8.0              11155.0               8.0
# 6                   8.0               1484.0               8.0
# 7                   9.0               4745.0               9.0
# 8                   6.0                729.0               6.0
# 9                   5.0               5165.0               6.0
# 10                  9.0               7909.0               9.0
# 11                  8.0               6245.0               8.0
# 12                  4.0               7119.0               5.0
# 13                  6.0               9614.0               6.0
# 14                  4.0               4678.0               4.0
# 15                  6.0               7139.0               6.0
# 16                  6.0               5131.0               8.0
# 17                  9.0               5658.0               9.0
# 18                  8.0              13950.0               9.0
# 19                  8.0               5409.0               8.0
# 20                  NaN                  NaN               NaN
# 21                  5.0               5622.0               6.0
# 22                  8.0                898.0               8.0
# 23                  9.0               8055.0               9.0
# 24                  9.0               5260.0               9.0
#
#     All Review Count
# 0          2434272.0
# 1           810784.0
# 2            48133.0
# 3           436866.0
# 4            95320.0
# 5           503004.0
# 6           138731.0
# 7            12906.0
# 8            19029.0
# 9           430085.0
# 10          214589.0
# 11          570996.0
# 12           59557.0
# 13          283307.0
# 14            4678.0
# 15          238337.0
# 16          278618.0
# 17            5658.0
# 18           96167.0
# 19            5409.0
# 20               NaN
# 21          239220.0
# 22           18845.0
# 23          367195.0
# 24          421842.0

# %%
import os
import pandas as pd
from datetime import datetime
 
dateCollected = datetime.now().strftime("%Y-%m-%d")

# Directory for CSVs
data_dir = os.path.join(os.getcwd(), "Steam Combined Data")
os.makedirs(data_dir, exist_ok=True)

# Save Overall Data
overall_file = os.path.join(data_dir, "Steam_Overall_Data.csv")

if os.path.exists(overall_file):
    overall_df = pd.read_csv(overall_file,index_col=False)
    print(overall_df)
    # # Standardize existing dates to ISO format
    # if "Date Collected" in overall_df.columns:
    #     overall_df["Date Collected"] = pd.to_datetime(overall_df["Date Collected"], errors="coerce").dt.strftime("%Y-%m-%d")

    # # Check for today's entry
    # if dateCollected in overall_df["Date Collected"].values:
    #     print("Data for today already exists in Steam_Overall_Data.csv, skipping save.")
    # else:
    #     overall_df = pd.concat([overall_df, game_data], ignore_index=True)
# Out:
#        Rank                          Game  Current     Peak   App ID  \
# 0       1.0              Counter-Strike 2   589411  1599759      730
# 1       2.0                 Marvel Rivals   296620   496193  2767030
# 2       3.0                        Dota 2   271976   714888      570
# 3       4.0           PUBG: BATTLEGROUNDS   109129   786821   578080
# 4       5.0  Kingdom Come: Deliverance II   106607   255607  1771300
# ...     ...                           ...      ...      ...      ...
# 4070  171.0                    Diablo® IV     5317    30532  2344520
# 4071  172.0                           DSX     5285     6771  1812620
# 4072  173.0   Call of Duty: Black Ops III     5250     7096   311210
# 4073  174.0                        Kenshi     5249     8861   233860
# 4074  175.0                 Summoners War     5191    10507  2426960
#
#       Player Hours                                             Genres  \
# 0        671649980                         ['Action', 'Free To Play']
# 1        194874053                         ['Action', 'Free To Play']
# 2        313409594             ['Action', 'Strategy', 'Free To Play']
# 3        213853616  ['Action', 'Adventure', 'Massively Multiplayer...
# 4         28754533                     ['Action', 'Adventure', 'RPG']
# ...            ...                                                ...
# 4070       7782228                                  ['Action', 'RPG']
# 4071       3453053                                      ['Utilities']
# 4072       2729058                            ['Action', 'Adventure']
# 4073       3864146  ['Action', 'Indie', 'RPG', 'Simulation', 'Stra...
# 4074       4683086                ['RPG', 'Strategy', 'Free To Play']
#
#       Release Date  Days Since Release Date Collected  \
# 0     Aug 21, 2012              4559.0     2025-02-13
# 1      Dec 5, 2024                70.0     2025-02-13
# 2      Jul 9, 2013              4237.0     2025-02-13
# 3     Dec 21, 2017              2611.0     2025-02-13
# 4      Feb 4, 2025                 9.0     2025-02-13
# ...            ...                 ...            ...
# 4070  Oct 17, 2023               755.0     2025-11-10
# 4071  Jun 24, 2022              1235.0     2025-11-10
# 4072   Nov 5, 2015              3658.0     2025-11-10
# 4073   Dec 6, 2018              2531.0     2025-11-10
# 4074   Jan 7, 2024               673.0     2025-11-10
#
#                                                    Tags  Recent Review Score  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# ...                                                 ...                  ...
# 4070  ['Action RPG', 'Hack and Slash', 'Loot', 'Isom...                  6.0
# 4071  ['Simulation', 'Indie', 'Controller', 'Utiliti...                  5.0
# 4072  ['Multiplayer', 'Zombies', 'FPS', 'Shooter', '...                  8.0
# 4073  ['Open World', 'Sandbox', 'RPG', 'Survival', '...                  9.0
# 4074  ['Free to Play', 'RPG', 'Strategy', 'Turn-Base...                  6.0
#
#       Recent Review Count  All Review Score  All Review Count
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
# ...                   ...               ...               ...
# 4070                841.0               6.0           15080.0
# 4071                237.0               5.0            2481.0
# 4072                947.0               8.0          110818.0
# 4073               1129.0               9.0           44431.0
# 4074                114.0               5.0            3549.0
#
# [4075 rows x 15 columns]
