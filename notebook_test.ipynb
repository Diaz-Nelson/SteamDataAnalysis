# %%
from functions import data_funcs

game_data, details_failed, game_failed, tags_failed  = data_funcs.get_game_data()
# Out:
# [INFO] Scraping Steam Charts...
# [INFO] Getting each game's details via Steam API...
# [INFO] Getting tags and reviews...
# [INFO] Combining dataframes...
# [SUCCESS] Game data successfully compiled.

# %%
import pandas as pd 

game_data["Rank"] = pd.to_numeric(game_data["Rank"].str.replace(r"\.", "", regex=True), errors="coerce").astype("Int64")
game_data["Current"] = pd.to_numeric(game_data["Current"].str.replace(r"\.", "", regex=True), errors="coerce").astype("Int64")
game_data["Peak"] = pd.to_numeric(game_data["Peak"].str.replace(r"\.", "", regex=True), errors="coerce").astype("Int64")
game_data["Player Hours	"] = pd.to_numeric(game_data["Player Hours	"].str.replace(r"\.", "", regex=True), errors="coerce").astype("Int64")


game_data
# Out:
#     Rank                               Game  Current     Peak   App ID  \
# 0      1                   Counter-Strike 2   728070  1603583      730
# 1      2                             Dota 2   397752   903542      570
# 2      3                        ARC Raiders   295319   415319  1808500
# 3      4                          Bongo Cat   130779   178015  3419430
# 4      5                PUBG: BATTLEGROUNDS   100744   751295   578080
# 5      6                      Marvel Rivals    99995   152267  2767030
# 6      7                    Path of Exile 2    91969   290305  2694490
# 7      8                           Warframe    86278   173377   230410
# 8      9                               Rust    84591   174558   252490
# 9     10                     Battlefield™ 6    80404   244715  2807960
# 10    11        Grand Theft Auto V Enhanced    68719   151971  3240220
# 11    12                      Geometry Dash    67043    92121   322170
# 12    13                    Baldur's Gate 3    63176    90162  1086940
# 13    14                   Where Winds Meet    57233   203810  3564740
# 14    15                   Wallpaper Engine    56986   145252   431960
# 15    16          Grand Theft Auto V Legacy    56717   136591   271590
# 16    17                     Stardew Valley    51924   125714   413150
# 17    18  Tom Clancy's Rainbow Six® Siege X    51144    64456   359550
# 18    19                        War Thunder    48028   119540   236390
# 19    20                       Apex Legends    47190   199799  1172470
# 20    21               Monster Hunter Wilds    43519   122339  2246340
# 21    22                      Call of Duty®    43428    83311  1938090
# 22    23                    Team Fortress 2    42738    92856      440
# 23    24                        Crosshair X    40859    66486  1366800
# 24    25                             VRChat    39315    59987   438100
#
#    Player Hours                                             Genres  \
# 0     695134509                             [Action, Free To Play]
# 1     434670697                   [Action, Strategy, Free To Play]
# 2     164373045                                           [Action]
# 3      71302464  [Casual, Indie, Massively Multiplayer, Simulat...
# 4     198631711  [Action, Adventure, Massively Multiplayer, Fre...
# 5      55836396                             [Action, Free To Play]
# 6      42489349  [Action, Adventure, Massively Multiplayer, RPG...
# 7      56762813                        [Action, RPG, Free To Play]
# 8      72364372  [Action, Adventure, Indie, Massively Multiplay...
# 9      77941516                                           [Action]
# 10     51620453                        [Action, Adventure, Racing]
# 11     36145940                                    [Action, Indie]
# 12     33851749                         [Adventure, RPG, Strategy]
# 13     77451281             [Action, Adventure, RPG, Free To Play]
# 14     59498636  [Casual, Indie, Animation & Modeling, Design &...
# 15     54733021                                [Action, Adventure]
# 16     37783260                           [Indie, RPG, Simulation]
# 17     28047520                             [Action, Free To Play]
# 18     40127922  [Action, Massively Multiplayer, Simulation, Fr...
# 19     57944146                  [Action, Adventure, Free To Play]
# 20     17622833                           [Action, Adventure, RPG]
# 21     34710110                                           [Action]
# 22     37639717                             [Action, Free To Play]
# 23     30546172  [Action, Adventure, Indie, Animation & Modelin...
# 24     28665746  [Adventure, Casual, Massively Multiplayer, Sim...
#
#     Release Date  Days Since Release  \
# 0   Aug 21, 2012                4872
# 1    Jul 9, 2013                4550
# 2   Oct 30, 2025                  54
# 3    Mar 5, 2025                 293
# 4   Dec 21, 2017                2924
# 5    Dec 5, 2024                 383
# 6    Dec 6, 2024                 382
# 7   Mar 25, 2013                4656
# 8    Feb 8, 2018                2875
# 9   Oct 10, 2025                  74
# 10   Mar 4, 2025                 294
# 11  Dec 22, 2014                4019
# 12   Aug 3, 2023                 873
# 13  Nov 14, 2025                  39
# 14  Nov 16, 2018                2594
# 15  Apr 13, 2015                3907
# 16  Feb 26, 2016                3588
# 17   Dec 1, 2015                3675
# 18  Aug 15, 2013                4513
# 19   Nov 4, 2020                1875
# 20  Feb 27, 2025                 299
# 21  Oct 27, 2022                1153
# 22  Oct 10, 2007                6649
# 23  Aug 17, 2020                1954
# 24   Feb 1, 2017                3247
#
#                                                  Tags  Recent Review Score  \
# 0   [FPS, Shooter, Multiplayer, Competitive, Actio...                    8
# 1   [Free to Play, MOBA, Multiplayer, Strategy, eS...                    8
# 2   [Extraction Shooter, Multiplayer, PvP, PvE, Th...                    8
# 3   [Cats, Free to Play, Clicker, Cute, Casual, Id...                    9
# 4   [Survival, Shooter, Battle Royale, Multiplayer...                    6
# 5   [Free to Play, Multiplayer, Hero Shooter, Thir...                    8
# 6   [Action RPG, Hack and Slash, RPG, Isometric, M...                    8
# 7   [Free to Play, Looter Shooter, Action RPG, Thi...                    8
# 8   [Survival, Crafting, Multiplayer, Open World, ...                    8
# 9   [FPS, Multiplayer, Action, Military, Singlepla...                    6
# 10  [Open World, Sexual Content, Action, Multiplay...                    8
# 11  [Difficult, Music, Level Editor, Great Soundtr...                    8
# 12  [RPG, Character Customization, Choices Matter,...                    9
# 13  [Open World, Multiplayer, Free to Play, Souls-...                    8
# 14  [Mature, Utilities, Anime, Software, Design & ...                    9
# 15  [Open World, Action, Multiplayer, Crime, Autom...                    8
# 16  [Farming Sim, Pixel Graphics, Multiplayer, Lif...                    9
# 17  [FPS, PvP, Multiplayer, Shooter, Tactical, eSp...                    6
# 18  [Free to Play, Simulation, Vehicular Combat, C...                    6
# 19  [Free to Play, Multiplayer, Battle Royale, FPS...                    6
# 20  [Hunting, Action, Multiplayer, Online Co-Op, C...                    5
# 21  [FPS, Multiplayer, Shooter, Singleplayer, Acti...                    5
# 22  [Free to Play, Hero Shooter, Multiplayer, FPS,...                    9
# 23  [Action, Indie, Utilities, Adventure, Shooter,...                    8
# 24  [VR, Free to Play, Multiplayer, Anime, Memes, ...                    6
#
#     Recent Review Count  All Review Score  All Review Count
# 0                 77658                 8           2453959
# 1                 45058                 8            818217
# 2                 73278                 8            122062
# 3                 31861                 9             19025
# 4                 16454                 5            438993
# 5                 22212                 6            254291
# 6                  7454                 6             86583
# 7                  6088                 8            282421
# 8                 18572                 8            507833
# 9                 43181                 6            123610
# 10                25526                 6             43157
# 11                16721                 8            215619
# 12                12582                 9            428390
# 13                52391                 8             50463
# 14                 7960                 9            216818
# 15                 9493                 8            573403
# 16                 9626                 9            370958
# 17                 9780                 8            741543
# 18                16989                 6            290472
# 19                 8818                 6            432315
# 20                 5352                 5             76546
# 21                 3430                 5            229456
# 22                15628                 8            723566
# 23                  954                 8             19430
# 24                 3438                 6            168281

# %%
game_data.dtypes
# Out:
# Rank                    Int64
# Game                   object
# Current                 Int64
# Peak                    Int64
# App ID                 object
# Player Hours           object
# Genres                 object
# Release Date           object
# Days Since Release      int64
# Tags                   object
# Recent Review Score     int64
# Recent Review Count     int64
# All Review Score        int64
# All Review Count        int64
# dtype: object

# %%
import os
import pandas as pd
from datetime import datetime
 
dateCollected = datetime.now().strftime("%Y-%m-%d")

# Directory for CSVs
data_dir = os.path.join(os.getcwd(), "Steam Combined Data")
os.makedirs(data_dir, exist_ok=True)

# Save Overall Data
overall_file = os.path.join(data_dir, "Steam_Overall_Data.csv")

if os.path.exists(overall_file):
    overall_df = pd.read_csv(overall_file,index_col=False)
    print(overall_df)
    # # Standardize existing dates to ISO format
    # if "Date Collected" in overall_df.columns:
    #     overall_df["Date Collected"] = pd.to_datetime(overall_df["Date Collected"], errors="coerce").dt.strftime("%Y-%m-%d")

    # # Check for today's entry
    # if dateCollected in overall_df["Date Collected"].values:
    #     print("Data for today already exists in Steam_Overall_Data.csv, skipping save.")
    # else:
    #     overall_df = pd.concat([overall_df, game_data], ignore_index=True)
# Out:
#        Rank                          Game  Current     Peak   App ID  \
# 0       1.0              Counter-Strike 2   589411  1599759      730
# 1       2.0                 Marvel Rivals   296620   496193  2767030
# 2       3.0                        Dota 2   271976   714888      570
# 3       4.0           PUBG: BATTLEGROUNDS   109129   786821   578080
# 4       5.0  Kingdom Come: Deliverance II   106607   255607  1771300
# ...     ...                           ...      ...      ...      ...
# 4070  171.0                    Diablo® IV     5317    30532  2344520
# 4071  172.0                           DSX     5285     6771  1812620
# 4072  173.0   Call of Duty: Black Ops III     5250     7096   311210
# 4073  174.0                        Kenshi     5249     8861   233860
# 4074  175.0                 Summoners War     5191    10507  2426960
#
#       Player Hours                                             Genres  \
# 0        671649980                         ['Action', 'Free To Play']
# 1        194874053                         ['Action', 'Free To Play']
# 2        313409594             ['Action', 'Strategy', 'Free To Play']
# 3        213853616  ['Action', 'Adventure', 'Massively Multiplayer...
# 4         28754533                     ['Action', 'Adventure', 'RPG']
# ...            ...                                                ...
# 4070       7782228                                  ['Action', 'RPG']
# 4071       3453053                                      ['Utilities']
# 4072       2729058                            ['Action', 'Adventure']
# 4073       3864146  ['Action', 'Indie', 'RPG', 'Simulation', 'Stra...
# 4074       4683086                ['RPG', 'Strategy', 'Free To Play']
#
#       Release Date  Days Since Release Date Collected  \
# 0     Aug 21, 2012              4559.0     2025-02-13
# 1      Dec 5, 2024                70.0     2025-02-13
# 2      Jul 9, 2013              4237.0     2025-02-13
# 3     Dec 21, 2017              2611.0     2025-02-13
# 4      Feb 4, 2025                 9.0     2025-02-13
# ...            ...                 ...            ...
# 4070  Oct 17, 2023               755.0     2025-11-10
# 4071  Jun 24, 2022              1235.0     2025-11-10
# 4072   Nov 5, 2015              3658.0     2025-11-10
# 4073   Dec 6, 2018              2531.0     2025-11-10
# 4074   Jan 7, 2024               673.0     2025-11-10
#
#                                                    Tags  Recent Review Score  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# ...                                                 ...                  ...
# 4070  ['Action RPG', 'Hack and Slash', 'Loot', 'Isom...                  6.0
# 4071  ['Simulation', 'Indie', 'Controller', 'Utiliti...                  5.0
# 4072  ['Multiplayer', 'Zombies', 'FPS', 'Shooter', '...                  8.0
# 4073  ['Open World', 'Sandbox', 'RPG', 'Survival', '...                  9.0
# 4074  ['Free to Play', 'RPG', 'Strategy', 'Turn-Base...                  6.0
#
#       Recent Review Count  All Review Score  All Review Count
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
# ...                   ...               ...               ...
# 4070                841.0               6.0           15080.0
# 4071                237.0               5.0            2481.0
# 4072                947.0               8.0          110818.0
# 4073               1129.0               9.0           44431.0
# 4074                114.0               5.0            3549.0
#
# [4075 rows x 15 columns]

# %%
import streamlit as st
import pandas as pd
from functions import filter_funcs as ff
from pymongo import MongoClient
import streamlit as st
import ast

try:
    from creds import CONNECTION_STRING
except ImportError:
    CONNECTION_STRING = st.secrets["CONNECTION_STRING"]


@st.cache_data(ttl=600)
def load_all_steam_data():
    client = MongoClient(CONNECTION_STRING)
    db = client["SteamCollectedData"]
    collection = db["Steam Data"]
    data = list(collection.find({}))
    df = pd.DataFrame(data)
    df.drop(columns=["_id"], inplace=True)

    list_columns = ["Genres", "Tags"]

    for col in list_columns:
        if col in df.columns:
            df[col] = df[col].apply(lambda x: 
                x if isinstance(x, list) 
                else ast.literal_eval(x) if isinstance(x, str) and x.startswith("[") 
                else []
            )

    return df

df = load_all_steam_data()
# Out:
# 2025-12-23 22:13:57.951 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-12-23 22:13:57.952 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-12-23 22:13:57.952 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:13:58.187
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\junio\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-23 22:13:58.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:13:58.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:13:58.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:13:58.699 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:13:58.700 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:13:58.701 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:14:14.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:14:14.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 22:14:14.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
print(df)
# Out:
#          Rank                               Game Current     Peak   App ID  \
# 0         1.0                   Counter-Strike 2  589411  1599759      730
# 1         2.0                      Marvel Rivals  296620   496193  2767030
# 2         3.0                             Dota 2  271976   714888      570
# 3         4.0                PUBG: BATTLEGROUNDS  109129   786821   578080
# 4         5.0       Kingdom Come: Deliverance II  106607   255607  1771300
# ...       ...                                ...     ...      ...      ...
# 170920  171.0              Monster Hunter: World    6585    27496   582010
# 170921  172.0  Halo: The Master Chief Collection    6503    12154   976730
# 170922  173.0                       Conan Exiles    6463     9557   440900
# 170923  174.0                      Borderlands 4    6441    15993  1285190
# 170924  175.0                              Hades    6412     9291  1145360
#
#        Player Hours                                             Genres  \
# 0         671649980                             [Action, Free To Play]
# 1         194874053                             [Action, Free To Play]
# 2         313409594                   [Action, Strategy, Free To Play]
# 3         213853616  [Action, Adventure, Massively Multiplayer, Fre...
# 4          28754533                           [Action, Adventure, RPG]
# ...             ...                                                ...
# 170920      8408694                                           [Action]
# 170921      3867417                                           [Action]
# 170922      3977372  [Action, Adventure, Massively Multiplayer, RPG...
# 170923      5190208                           [Action, Adventure, RPG]
# 170924      3201105                               [Action, Indie, RPG]
#
#         Release Date  Days Since Release Date Collected  \
# 0       Aug 21, 2012              4559.0     2025-02-13
# 1        Dec 5, 2024                70.0     2025-02-13
# 2        Jul 9, 2013              4237.0     2025-02-13
# 3       Dec 21, 2017              2611.0     2025-02-13
# 4        Feb 4, 2025                 9.0     2025-02-13
# ...              ...                 ...            ...
# 170920   Aug 8, 2018              2693.0     2025-12-22
# 170921   Dec 3, 2019              2211.0     2025-12-22
# 170922   May 8, 2018              2785.0     2025-12-22
# 170923  Sep 11, 2025               102.0     2025-12-22
# 170924  Sep 17, 2020              1922.0     2025-12-22
#
#                                                      Tags  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 170920  [Co-op, Multiplayer, Action, Open World, RPG, ...
# 170921  [Great Soundtrack, FPS, Classic, Multiplayer, ...
# 170922  [Survival, Open World, Nudity, Building, Open ...
# 170923  [FPS, PvE, Looter Shooter, Open World, Action ...
# 170924  [Action Roguelike, Roguelite, Hack and Slash, ...
#
#         Recent Review Score  Recent Review Count  All Review Score  \
# 0                       NaN                  NaN               NaN
# 1                       NaN                  NaN               NaN
# 2                       NaN                  NaN               NaN
# 3                       NaN                  NaN               NaN
# 4                       NaN                  NaN               NaN
# ...                     ...                  ...               ...
# 170920                  8.0               1287.0               8.0
# 170921                  8.0               2060.0               8.0
# 170922                  8.0                463.0               6.0
# 170923                  6.0               2138.0               5.0
# 170924                  9.0               2030.0               9.0
#
#         All Review Count
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 170920          112108.0
# 170921          157294.0
# 170922           37096.0
# 170923           38528.0
# 170924          136316.0
#
# [170925 rows x 15 columns]

# %%
df.dtypes
# Out:
# Rank                   float64
# Game                    object
# Current                  int64
# Peak                     int64
# App ID                  object
# Player Hours             int64
# Genres                  object
# Release Date            object
# Days Since Release     float64
# Date Collected          object
# Tags                    object
# Recent Review Score    float64
# Recent Review Count    float64
# All Review Score       float64
# All Review Count       float64
# dtype: object

# %%
from functions import ml_funcs

sucess_df = ml_funcs.forest_ml(df)
print(sucess_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from functions import ml_funcs
# ----> 3 sucess_df = ml_funcs.forest_ml(df)
#       4 print(sucess_df)
#
# File c:\CODE FILES\MyCodeStuff\Projects\SteamDataProject\SteamDataAnalysis\functions\ml_funcs.py:38, in forest_ml(data)
#      35 tags_expanded = pd.DataFrame(data['Tags'].tolist(), index=data.index).stack().reset_index(level=1, drop=True)
#      36 tag_dummies = pd.get_dummies(tags_expanded).groupby(level=0).sum()
# ---> 38 data['Popularity'] = data.apply(calc_sucess_score, axis=1)
#      39 data = data.dropna(subset=['Tags','Popularity'])
#      40 test_with_tags = pd.concat([data, tag_dummies], axis=1).dropna()
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\junio\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File c:\CODE FILES\MyCodeStuff\Projects\SteamDataProject\SteamDataAnalysis\functions\ml_funcs.py:26, in calc_sucess_score(gamedata)
#      21 current_players = gamedata['Current']
#      22 peak_players = gamedata['Peak']
#      23 success_score = (
#      24     (recent_review_score * math.log(recent_review_count)) +
#      25     (all_review_score * math.log(all_review_count)) +
# ---> 26     (current_players/peak_players )+
#      27     (math.log(player_hours)/days_since_release) +
#      28     (math.log(days_since_release)/math.log(current_players))+
#      29     (recent_review_count/all_review_count)
#      30 )
#      32 return(math.log(success_score))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
